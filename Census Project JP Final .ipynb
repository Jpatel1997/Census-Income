# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('C:\\Users\\Admin\\Desktop\\Census Income project\\census.csv', skipinitialspace=True)

# %%
data.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country Unnamed: 14
# 0          2174             0              40  United-States       <=50K
# 1             0             0              13  United-States       <=50K
# 2             0             0              40  United-States       <=50K
# 3             0             0              40  United-States       <=50K
# 4             0             0              40           Cuba       <=50K

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'Unnamed: 14'],
#       dtype='object')

# %%
data['occupation'].value_counts()
# Out:
# Prof-specialty       4140
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3770
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
data.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# Unnamed: 14       0
# dtype: int64

# %%
income=data['Unnamed: 14']

# %%
data.rename(columns={'Unnamed: 14':'income'},inplace=True)

# %%
data.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
data.rename(columns={'Unnamed: 14':'income'},inplace=True)

# %%
data.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data.columns=data.columns.str.replace('-',' ')

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education num',
#        'marital status', 'occupation', 'relationship', 'race', 'sex',
#        'capital gain', 'capital loss', 'hours per week', 'native country',
#        'income'],
#       dtype='object')

# %%
data['workclass'].unique()
# Out:
# array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#        'Local-gov', '?', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
data['workclass'].nunique()
# Out:
# 9

# %%
data['workclass'].value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
data= data.replace('?',np.nan)

# %%
data.head(16)
# Out:
#     age         workclass  fnlwgt     education  education num  \
# 0    39         State-gov   77516     Bachelors             13
# 1    50  Self-emp-not-inc   83311     Bachelors             13
# 2    38           Private  215646       HS-grad              9
# 3    53           Private  234721          11th              7
# 4    28           Private  338409     Bachelors             13
# 5    37           Private  284582       Masters             14
# 6    49           Private  160187           9th              5
# 7    52  Self-emp-not-inc  209642       HS-grad              9
# 8    31           Private   45781       Masters             14
# 9    42           Private  159449     Bachelors             13
# 10   37           Private  280464  Some-college             10
# 11   30         State-gov  141297     Bachelors             13
# 12   23           Private  122272     Bachelors             13
# 13   32           Private  205019    Assoc-acdm             12
# 14   40           Private  121772     Assoc-voc             11
# 15   34           Private  245487       7th-8th              4
#
#            marital status         occupation   relationship  \
# 0           Never-married       Adm-clerical  Not-in-family
# 1      Married-civ-spouse    Exec-managerial        Husband
# 2                Divorced  Handlers-cleaners  Not-in-family
# 3      Married-civ-spouse  Handlers-cleaners        Husband
# 4      Married-civ-spouse     Prof-specialty           Wife
# 5      Married-civ-spouse    Exec-managerial           Wife
# 6   Married-spouse-absent      Other-service  Not-in-family
# 7      Married-civ-spouse    Exec-managerial        Husband
# 8           Never-married     Prof-specialty  Not-in-family
# 9      Married-civ-spouse    Exec-managerial        Husband
# 10     Married-civ-spouse    Exec-managerial        Husband
# 11     Married-civ-spouse     Prof-specialty        Husband
# 12          Never-married       Adm-clerical      Own-child
# 13          Never-married              Sales  Not-in-family
# 14     Married-civ-spouse       Craft-repair        Husband
# 15     Married-civ-spouse   Transport-moving        Husband
#
#                   race     sex  capital gain  capital loss  hours per week  \
# 0                White    Male          2174             0              40
# 1                White    Male             0             0              13
# 2                White    Male             0             0              40
# 3                Black    Male             0             0              40
# 4                Black  Female             0             0              40
# 5                White  Female             0             0              40
# 6                Black  Female             0             0              16
# 7                White    Male             0             0              45
# 8                White  Female         14084             0              50
# 9                White    Male          5178             0              40
# 10               Black    Male             0             0              80
# 11  Asian-Pac-Islander    Male             0             0              40
# 12               White  Female             0             0              30
# 13               Black    Male             0             0              50
# 14  Asian-Pac-Islander    Male             0             0              40
# 15  Amer-Indian-Eskimo    Male             0             0              45
#
#    native country income
# 0   United-States  <=50K
# 1   United-States  <=50K
# 2   United-States  <=50K
# 3   United-States  <=50K
# 4            Cuba  <=50K
# 5   United-States  <=50K
# 6         Jamaica  <=50K
# 7   United-States   >50K
# 8   United-States   >50K
# 9   United-States   >50K
# 10  United-States   >50K
# 11          India   >50K
# 12  United-States  <=50K
# 13  United-States  <=50K
# 14            NaN   >50K
# 15         Mexico  <=50K

# %%
data.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# Unnamed: 14       0
# dtype: int64

# %%
data.shape
# Out:
# (32561, 15)

# %%
data=data.dropna()

# %%
data.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education num     0
# marital status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital gain      0
# capital loss      0
# hours per week    0
# native country    0
# income            0
# dtype: int64

# %%
data.shape
# Out:
# (30162, 15)

# %%
#Extract the “education” column and store it in “census_ed”
census_ed = data[['education']]
census_ed
# Out:
#         education
# 0       Bachelors
# 1       Bachelors
# 2         HS-grad
# 3            11th
# 4       Bachelors
# ...           ...
# 32556  Assoc-acdm
# 32557     HS-grad
# 32558     HS-grad
# 32559     HS-grad
# 32560     HS-grad
#
# [30162 rows x 1 columns]

# %%
#Extract all the columns from “age” to “relationship” and store it in “census_seq”.
census_seq=data.iloc[:,:8]
census_seq
# Out:
#        age         workclass  fnlwgt   education  education num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital status         occupation   relationship
# 0           Never-married       Adm-clerical  Not-in-family
# 1      Married-civ-spouse    Exec-managerial        Husband
# 2                Divorced  Handlers-cleaners  Not-in-family
# 3      Married-civ-spouse  Handlers-cleaners        Husband
# 4      Married-civ-spouse     Prof-specialty           Wife
# ...                   ...                ...            ...
# 32556  Married-civ-spouse       Tech-support           Wife
# 32557  Married-civ-spouse  Machine-op-inspct        Husband
# 32558             Widowed       Adm-clerical      Unmarried
# 32559       Never-married       Adm-clerical      Own-child
# 32560  Married-civ-spouse    Exec-managerial           Wife
#
# [30162 rows x 8 columns]

# %%
#Extract the column number “5”, “8”, “11” and store it in “census_col”.
census_col=data.iloc[:,[5,8,11]]
census_col
# Out:
#            marital status   race  capital loss
# 0           Never-married  White             0
# 1      Married-civ-spouse  White             0
# 2                Divorced  White             0
# 3      Married-civ-spouse  Black             0
# 4      Married-civ-spouse  Black             0
# ...                   ...    ...           ...
# 32556  Married-civ-spouse  White             0
# 32557  Married-civ-spouse  White             0
# 32558             Widowed  White             0
# 32559       Never-married  White             0
# 32560  Married-civ-spouse  White             0
#
# [30162 rows x 3 columns]

# %%
#Extract all the male employees who work in state-gov and store it in “male_gov”.
male_gov=data[(data['sex']=='Male') & (data['workclass']=='State-gov')]
male_gov
# Out:
#        age  workclass  fnlwgt     education  education num  \
# 0       39  State-gov   77516     Bachelors             13
# 11      30  State-gov  141297     Bachelors             13
# 34      22  State-gov  311512  Some-college             10
# 48      41  State-gov  101603     Assoc-voc             11
# 123     29  State-gov  267989     Bachelors             13
# ...    ...        ...     ...           ...            ...
# 32163   36  State-gov  135874     Bachelors             13
# 32241   45  State-gov  231013     Bachelors             13
# 32321   54  State-gov  138852       HS-grad              9
# 32324   42  State-gov  138162  Some-college             10
# 32360   58  State-gov  200316       HS-grad              9
#
#            marital status       occupation   relationship                race  \
# 0           Never-married     Adm-clerical  Not-in-family               White
# 11     Married-civ-spouse   Prof-specialty        Husband  Asian-Pac-Islander
# 34     Married-civ-spouse    Other-service        Husband               Black
# 48     Married-civ-spouse     Craft-repair        Husband               White
# 123    Married-civ-spouse   Prof-specialty        Husband               White
# ...                   ...              ...            ...                 ...
# 32163  Married-civ-spouse            Sales        Husband               White
# 32241            Divorced  Protective-serv  Not-in-family               White
# 32321  Married-civ-spouse   Prof-specialty        Husband               White
# 32324            Divorced     Adm-clerical      Own-child               White
# 32360  Married-civ-spouse     Craft-repair        Husband               White
#
#         sex  capital gain  capital loss  hours per week native country income
# 0      Male          2174             0              40  United-States  <=50K
# 11     Male             0             0              40          India   >50K
# 34     Male             0             0              15  United-States  <=50K
# 48     Male             0             0              40  United-States  <=50K
# 123    Male             0             0              50  United-States   >50K
# ...     ...           ...           ...             ...            ...    ...
# 32163  Male             0             0              40  United-States  <=50K
# 32241  Male             0             0              40  United-States  <=50K
# 32321  Male             0             0              40  United-States  <=50K
# 32324  Male             0             0              40  United-States  <=50K
# 32360  Male             0             0              40  United-States  <=50K
#
# [795 rows x 15 columns]

# %%
#Extract all the 39 year olds who either have a bachelor's
#degree or who are native of the United States and store the result in “census_us”.
census_us=data[(data["age"]==39) & ((data["education"]=='Bachelors') | (data["native country"]=='United-States'))]
census_us
# Out:
#        age         workclass  fnlwgt     education  education num  \
# 0       39         State-gov   77516     Bachelors             13
# 28      39           Private  367260       HS-grad              9
# 129     39           Private  365739  Some-college             10
# 166     39       Federal-gov  235485    Assoc-acdm             12
# 320     39  Self-emp-not-inc  174308       HS-grad              9
# ...    ...               ...     ...           ...            ...
# 32146   39           Private  117381  Some-college             10
# 32260   39       Federal-gov  232036  Some-college             10
# 32428   39       Federal-gov  110622     Bachelors             13
# 32468   39  Self-emp-not-inc  193689       HS-grad              9
# 32545   39         Local-gov  111499    Assoc-acdm             12
#
#            marital status        occupation   relationship  \
# 0           Never-married      Adm-clerical  Not-in-family
# 28               Divorced   Exec-managerial  Not-in-family
# 129              Divorced      Craft-repair  Not-in-family
# 166         Never-married   Exec-managerial  Not-in-family
# 320    Married-civ-spouse   Exec-managerial        Husband
# ...                   ...               ...            ...
# 32146            Divorced  Transport-moving  Not-in-family
# 32260  Married-civ-spouse      Adm-clerical        Husband
# 32428  Married-civ-spouse      Adm-clerical           Wife
# 32468       Never-married   Exec-managerial  Not-in-family
# 32545  Married-civ-spouse      Adm-clerical           Wife
#
#                      race     sex  capital gain  capital loss  hours per week  \
# 0                   White    Male          2174             0              40
# 28                  White    Male             0             0              80
# 129                 White    Male             0             0              40
# 166                 White    Male             0             0              42
# 320                 White    Male             0             0              40
# ...                   ...     ...           ...           ...             ...
# 32146               White    Male             0             0              65
# 32260               White    Male             0             0              40
# 32428  Asian-Pac-Islander  Female             0             0              40
# 32468               White    Male             0             0              65
# 32545               White  Female             0             0              20
#
#       native country income
# 0      United-States  <=50K
# 28     United-States  <=50K
# 129    United-States  <=50K
# 166    United-States  <=50K
# 320    United-States  <=50K
# ...              ...    ...
# 32146  United-States  <=50K
# 32260  United-States   >50K
# 32428    Philippines  <=50K
# 32468  United-States  <=50K
# 32545  United-States   >50K
#
# [742 rows x 15 columns]

# %%
#Extract 200 random rows from the “census” data frame and store it in “census_200”.
census_200 = data.sample(200)
census_200
# Out:
#        age         workclass  fnlwgt     education  education num  \
# 22536   60         Local-gov  165982       Masters             14
# 15115   35           Private  257042  Some-college             10
# 4457    31         State-gov   93589       HS-grad              9
# 1651    36  Self-emp-not-inc  136028           9th              5
# 5535    25           Private   49092     Bachelors             13
# ...    ...               ...     ...           ...            ...
# 30139   43           Private  233130       HS-grad              9
# 1069    36           Private  117312    Assoc-acdm             12
# 15133   46           Private  241935          11th              7
# 30764   30           Private  311696          11th              7
# 29506   34           Private  169583       Masters             14
#
#            marital status       occupation   relationship   race     sex  \
# 22536  Married-civ-spouse  Exec-managerial        Husband  White    Male
# 15115  Married-civ-spouse   Prof-specialty        Husband  White    Male
# 4457             Divorced  Protective-serv      Own-child  Other    Male
# 1651   Married-civ-spouse     Craft-repair        Husband  White    Male
# 5535        Never-married    Other-service      Own-child  White    Male
# ...                   ...              ...            ...    ...     ...
# 30139            Divorced            Sales  Not-in-family  White    Male
# 1069             Divorced     Tech-support  Not-in-family  White  Female
# 15133  Married-civ-spouse    Other-service        Husband  Black    Male
# 30764  Married-civ-spouse    Other-service           Wife  Black  Female
# 29506       Never-married  Exec-managerial  Not-in-family  White  Female
#
#        capital gain  capital loss  hours per week native country income
# 22536             0             0              50  United-States   >50K
# 15115             0             0              50  United-States  <=50K
# 4457              0             0              40  United-States  <=50K
# 1651              0             0              30  United-States  <=50K
# 5535              0             0              40  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 30139             0             0              20  United-States  <=50K
# 1069              0             0              60  United-States  <=50K
# 15133          7688             0              40  United-States   >50K
# 30764             0             0              30  United-States  <=50K
# 29506             0             0              50  United-States  <=50K
#
# [200 rows x 15 columns]

# %%
#Get the count of different levels of the “workclass” column.

data['workclass'].value_counts()
# Out:
# Private             22286
# Self-emp-not-inc     2499
# Local-gov            2067
# State-gov            1279
# Self-emp-inc         1074
# Federal-gov           943
# Without-pay            14
# Name: workclass, dtype: int64

# %%
#Calculate the mean of the “capital.gain” column grouped according to “workclass
df2 = data.groupby(["workclass"])["capital gain"].mean()

# %%
df2
# Out:
# workclass
# Federal-gov          832.321315
# Local-gov            829.230285
# Private              879.858207
# Self-emp-inc        4810.746741
# Self-emp-not-inc    1913.134454
# State-gov            684.306489
# Without-pay          487.857143
# Name: capital gain, dtype: float64

# %%
# Calculate the percentage of married people in the census data.
# Calculate the percentage of high school graduates earning more than 50,000 annually

# %%
cal = data[(data['marital status']=='Married-civ-spouse') | (data['marital status']== 'Married-AF-spouse')]

(len(cal)/len(data))*100
# Out:
# 46.7011471387839

# %%
#Calculate the percentage of people from the United States who are private employees and earn less than 50,000 annually.

# %%
data.groupby(['native country','workclass']).size()
# Out:
# native country  workclass
# Cambodia        Federal-gov          1
#                 Private             16
#                 Self-emp-not-inc     1
# Canada          Federal-gov          2
#                 Local-gov            6
#                                     ..
# Vietnam         State-gov            1
# Yugoslavia      Local-gov            1
#                 Private             13
#                 Self-emp-inc         1
#                 Self-emp-not-inc     1
# Length: 190, dtype: int64

# %% [markdown]
# # linear regression

# %%
data.head()
# Out:
#    age         workclass  fnlwgt  education  education num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital gain  capital loss  hours per week native country income
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30162 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             30162 non-null  int64
#  1   workclass       30162 non-null  object
#  2   fnlwgt          30162 non-null  int64
#  3   education       30162 non-null  object
#  4   education num   30162 non-null  int64
#  5   marital status  30162 non-null  object
#  6   occupation      30162 non-null  object
#  7   relationship    30162 non-null  object
#  8   race            30162 non-null  object
#  9   sex             30162 non-null  object
#  10  capital gain    30162 non-null  int64
#  11  capital loss    30162 non-null  int64
#  12  hours per week  30162 non-null  int64
#  13  native country  30162 non-null  object
#  14  income          30162 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
x= data[['education num']]
y= data['hours per week']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=.30, random_state=1)

# %%
l_model = LinearRegression()
l_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
l_model.fit(x_train,y_train)
y_pred=l_model.predict(x_test)

# %%
y_pred
# Out:
# array([41.34761171, 40.68924142, 41.22790802, ..., 40.56953773,
#        41.34761171, 40.56953773])

# %%
from sklearn.metrics import *

# %%
accuracy = r2_score(y_test,y_pred)
accuracy
# Out:
# 0.0001703969360945523

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 138.52199858910788

# %% [markdown]
# # logistic

# %%
data.head()
# Out:
#    age         workclass  fnlwgt  education  education num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital gain  capital loss  hours per week native country income
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
x=data['occupation']
x=pd.DataFrame(x)

# %%
x
# Out:
#               occupation
# 0           Adm-clerical
# 1        Exec-managerial
# 2      Handlers-cleaners
# 3      Handlers-cleaners
# 4         Prof-specialty
# ...                  ...
# 32556       Tech-support
# 32557  Machine-op-inspct
# 32558       Adm-clerical
# 32559       Adm-clerical
# 32560    Exec-managerial
#
# [30162 rows x 1 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
l=LabelEncoder()

# %%
x=l.fit_transform(x)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
x
# Out:
# array([0, 3, 5, ..., 0, 0, 3])

# %%
x=pd.DataFrame(x)

# %%
x
# Out:
#         0
# 0       0
# 1       3
# 2       5
# 3       5
# 4       9
# ...    ..
# 30157  12
# 30158   6
# 30159   0
# 30160   0
# 30161   3
#
# [30162 rows x 1 columns]

# %%
data['income'].value_counts()
# Out:
# <=50K    22654
# >50K      7508
# Name: income, dtype: int64

# %%
y=data['income'].replace('<=50K',0).replace('>50K',1)

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32556    0
# 32557    1
# 32558    0
# 32559    0
# 32560    1
# Name: income, Length: 30162, dtype: int64

# %%
from sklearn.linear_model import *
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=1)

# %%
lo=LogisticRegression()

# %%
lo.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lo.predict(x_test)

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.7480384572880981

# %% [markdown]
# #Multiple Logistic regression

# %%
#Build a simple logistic regression model as follows:
#● Divide the dataset into training and test sets in 65:35 ratio.
#● Build a logistic regression model where the dependent variable is “X”(yearly income) and the independent variable is “occupation”.
#● Predict the values on the test set.
#● Build a confusion matrix and find the accuracy

# %%
col_list = list(data.columns)
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
for i in col_list:
    data[i]=labelencoder.fit_transform(data[i])

# %%
data.head()
# Out:
#    age  workclass  fnlwgt  education  education num  marital status  \
# 0   22          5    2491          9             12               4
# 1   33          4    2727          9             12               2
# 2   21          2   13188         11              8               0
# 3   36          2   14354          1              6               2
# 4   11          2   18120          9             12               2
#
#    occupation  relationship  race  sex  capital gain  capital loss  \
# 0           0             1     4    1            24             0
# 1           3             0     4    1             0             0
# 2           5             1     4    1             0             0
# 3           5             0     2    1             0             0
# 4           9             5     2    0             0             0
#
#    hours per week  native country  income
# 0              39              38       0
# 1              12              38       0
# 2              39              38       0
# 3              39              38       0
# 4              39               4       0

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
print(data.columns.tolist())
# Out:
# ['age', 'workclass', 'fnlwgt', 'education', 'education num', 'marital status', 'occupation', 'relationship', 'race', 'sex', 'capital gain', 'capital loss', 'hours per week', 'native country', 'income']

# %%
x = data.iloc[:,[0,1,3]]

# %%
x
# Out:
#        age  workclass  education
# 0       22          5          9
# 1       33          4          9
# 2       21          2         11
# 3       36          2          1
# 4       11          2          9
# ...    ...        ...        ...
# 32556   10          2          7
# 32557   23          2         11
# 32558   41          2         11
# 32559    5          2         11
# 32560   35          3         11
#
# [30162 rows x 3 columns]

# %%
y = data['income']

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32556    0
# 32557    1
# 32558    0
# 32559    0
# 32560    1
# Name: income, Length: 30162, dtype: int32

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=1)

# %%
lo=LogisticRegression()

# %%
lo.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lo.predict(x_test)

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.7293220619923753

# %%
x_test
# Out:
#        age  workclass  education
# 12488   13          2         11
# 5130    23          2          0
# 8616     6          2          9
# 15453   30          5         11
# 13555   26          2          7
# ...    ...        ...        ...
# 20348    6          2          9
# 13190   15          2          8
# 13247   27          2         15
# 8125    36          4          9
# 9218    33          2          9
#
# [6033 rows x 3 columns]

# %%
pd.DataFrame(lo.predict_proba(x_test))
# Out:
#         0    1
# 0    0.82 0.18
# 1    0.85 0.15
# 2    0.88 0.12
# 3    0.69 0.31
# 4    0.77 0.23
# ...   ...  ...
# 6028 0.88 0.12
# 6029 0.83 0.17
# 6030 0.67 0.33
# 6031 0.66 0.34
# 6032 0.68 0.32
#
# [6033 rows x 2 columns]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
c1=confusion_matrix(y_test,y_pred)
c1
# Out:
# array([[4349,  134],
#        [1499,   51]], dtype=int64)

# %%
(4349+51)/(4349+51+134+1499)
# Out:
# 0.7293220619923753

# %%
sen=c1[0,0]/(c1[0,0]+c1[0,1])
sen
# Out:
# 0.9701093018068258

# %%
sep=c1[1,1]/(c1[1,1]+c1[1,0])
sep
# Out:
# 0.032903225806451615

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7293220619923753

# %% [markdown]
# # Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
data['education'].value_counts()
# Out:
# 11    9840
# 15    6678
# 9     5044
# 12    1627
# 8     1307
# 1     1048
# 7     1008
# 0      820
# 5      557
# 14     542
# 6      455
# 2      377
# 10     375
# 4      288
# 3      151
# 13      45
# Name: education, dtype: int64

# %%
data.head()
# Out:
#    age  workclass  fnlwgt  education  education num  marital status  \
# 0   22          5    2491          9             12               4
# 1   33          4    2727          9             12               2
# 2   21          2   13188         11              8               0
# 3   36          2   14354          1              6               2
# 4   11          2   18120          9             12               2
#
#    occupation  relationship  race  sex  capital gain  capital loss  \
# 0           0             1     4    1            24             0
# 1           3             0     4    1             0             0
# 2           5             1     4    1             0             0
# 3           5             0     2    1             0             0
# 4           9             5     2    0             0             0
#
#    hours per week  native country  income
# 0              39              38       0
# 1              12              38       0
# 2              39              38       0
# 3              39              38       0
# 4              39               4       0

# %%
data.education= data.education.replace(['Preschool', '1st-4th', '5th-6th', '7th-8th', '9th','10th', '11th', '12th'], 'School')
data.education = data.education.replace(['Assoc-voc', 'Assoc-acdm', 'Prof-school', 'Some-college'], 'Higher')

# %%
data=data.apply(l.fit_transform)

# %%
data.head(1)
# Out:
#    age  workclass  fnlwgt  education  education num  marital status  \
# 0   22          5    2491          9             12               4
#
#    occupation  relationship  race  sex  capital gain  capital loss  \
# 0           0             1     4    1            24             0
#
#    hours per week  native country  income
# 0              39              38       0

# %%
x=data.iloc[:,:-1]
y=data.iloc[:,-1]

# %%
x
# Out:
#        age  workclass  fnlwgt  education  education num  marital status  \
# 0       22          5    2491          9             12               4
# 1       33          4    2727          9             12               2
# 2       21          2   13188         11              8               0
# 3       36          2   14354          1              6               2
# 4       11          2   18120          9             12               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   10          2   15471          7             11               2
# 32557   23          2    7555         11              8               2
# 32558   41          2    7377         11              8               6
# 32559    5          2   12060         11              8               4
# 32560   35          3   16689         11              8               2
#
#        occupation  relationship  race  sex  capital gain  capital loss  \
# 0               0             1     4    1            24             0
# 1               3             0     4    1             0             0
# 2               5             1     4    1             0             0
# 3               5             0     2    1             0             0
# 4               9             5     2    0             0             0
# ...           ...           ...   ...  ...           ...           ...
# 32556          12             5     4    0             0             0
# 32557           6             0     4    1             0             0
# 32558           0             4     4    0             0             0
# 32559           0             3     4    1             0             0
# 32560           3             5     4    0           107             0
#
#        hours per week  native country
# 0                  39              38
# 1                  12              38
# 2                  39              38
# 3                  39              38
# 4                  39               4
# ...               ...             ...
# 32556              37              38
# 32557              39              38
# 32558              39              38
# 32559              19              38
# 32560              39              38
#
# [30162 rows x 14 columns]

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32556    0
# 32557    1
# 32558    0
# 32559    0
# 32560    1
# Name: income, Length: 30162, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=1)

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dt.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7997568792131727

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier(n_estimators=300)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=300)

# %%
y_pred=rf.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8556746601834457

# %% [markdown]
# # Thank You
